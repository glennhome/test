# %% [markdown]
# # ADULT Dataset 分析及預測報告 <h1>
#                                                                                                                2019-09-02
#                                                                                                                    吳明宗

# %% [markdown]
# # 說明：
# * 資料來源：使用UCI Adult Data Set。 http://archive.ics.uci.edu/ml/datasets/Adult <br>
# * 分析流程：<br>
#     1.資料檢視<br>
#     2.資料工程<br>
#     3.建立模型<br>

# %% [markdown]
# # 零、事前準備

# %% [markdown]
# # Import

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import xgboost as xgb
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn.externals import joblib
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.metrics import accuracy_score, log_loss, confusion_matrix, make_scorer
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

from keras import layers
from keras import optimizers
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD, RMSprop, Adagrad

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def plot_history(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

def train_to_test_split(train_x, train_y):
    sc = MinMaxScaler()
    train_x = sc.fit_transform(train_x)
    joblib.dump(sc.fit(train_x), scaler_filename) 
    return train_test_split(train_x, train_y, test_size=0.3, random_state=SEED)

def grid_search(clf, parameters, X_train, y_train):
    acc_scorer = make_scorer(accuracy_score)
    grid_obj = GridSearchCV(clf, parameters, scoring=acc_scorer, n_jobs=-1, cv=5)
    grid_obj = grid_obj.fit(X_train, y_train.values.ravel())
    clf = grid_obj.best_estimator_
    return(clf)
    
def grid_classifier(clf):
    clf_name = clf.__class__.__name__
    parameters = parameter_set(clf_name)
    print(parameters)
    # return predictions from gird search best model
    clf = grid_search(clf, parameters, X_train, y_train)
    print('-'*5)
    print('Get Grid Parameters')
    print(clf.get_params())
    # fit best model
    clf.fit(X_train, y_train.values.ravel())
    model_name = 'model/'+ clf_name + 'Grid' +'_00001.pkl'
    joblib.dump(clf, model_name) 
    predictions = clf.predict(X_test) 
    if clf_name == 'XGBClassifier':
        predictions = [value for value in predictions]
    return clf, predictions

def get_oof(clf, X_train, y_train, X_test):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))
    i = 0
    for train_index, test_index in kf.split(X_train):
        x_tr = X_train[train_index]
        y_tr = y_train.values.ravel()[train_index]
        x_te = X_train[test_index]
        clf.fit(x_tr, y_tr)
        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(X_test)
        i += 1
    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

def parameter_set(clf_name):
    if clf_name == 'RandomForestClassifier':
        parameters = {'n_estimators': [100, 150, 200], 
#               'max_features': ['log2', 'sqrt','auto'], 
              'criterion': ['entropy', 'gini'],
#               'max_depth': list(range(2,10)), 
#               'min_samples_split': list(range(2,5)),
#               'min_samples_leaf': list(range(1,5)),
              'n_jobs': [-1],
              'verbose': [1]
             }
    if clf_name == 'DecisionTreeClassifier':
        parameters = {
              'max_depth': list(range(2,10)), 
              'min_samples_split': list(range(2,10))
             }
    if clf_name == 'AdaBoostClassifier':
        parameters = {
            "n_estimators" : [150, 200],
            "algorithm" :  ["SAMME", "SAMME.R"],
            'learning_rate': [0.2, 0.5, 0.9]
             }
    if clf_name == 'GradientBoostingClassifier':
        parameters = {
            "loss":["deviance"],
            "learning_rate": [0.2, 0.5, 0.9],
#             "min_samples_split": list(range(2,5)),
#             "min_samples_leaf": list(range(1,5)),
            "max_depth": [3, 8],
#             "max_features":["log2","sqrt"],
#             "criterion": ["friedman_mse",  "mae"],
#             "subsample": [0.5, 0.8, 0.9, 1.0],
#             "n_estimators": [100, 150]
             }
    if clf_name == 'XGBClassifier':
        parameters = {
            'learning_rate': [0.2, 0.5, 0.9],
#             'max_depth': list(range(5,10)),
#             'min_child_weight': list(range(3,10)),
            'gamma': np.linspace(0, 0.9, 3),
#             'subsample': [0.8, 0.9],
#             'colsample_bytree': [0.3, 0.4, 0.5 , 0.7, 0.8, 0.9],
            'objective': ['binary:logistic']
        }
    if clf_name == 'ExtraTreesClassifier':
        parameters = {
            "n_estimators" : [100, 150, 200],
            'criterion': ['entropy', 'gini']
        }
    return(parameters)

# %%
# Dirs -------------------------------------------
scaler_filename = "model/scaler.save"

# Config -----------------------------------------
SEED = 111 
NFOLDS = 5

# Load Data --------------------------------------
dt = pd.read_csv("data/adult.data.csv").sample(frac=1)

# %%
dt.head()
# Out:
#        age      workclass  fnlwgt   education  education-num  \
# 24564   41        Private   88368     HS-grad              9
# 29642   45   Self-emp-inc  204196   Bachelors             13
# 4925    28              ?  290267   Bachelors             13
# 15568   31        Private  115488     HS-grad              9
# 15873   58        Private  314153     HS-grad              9
#
#             marital-status        occupation relationshiprace    race  \
# 24564        Never-married             Sales    Not-in-family   White
# 29642             Divorced   Exec-managerial        Unmarried   White
# 4925         Never-married                 ?    Not-in-family   White
# 15568   Married-civ-spouse   Farming-fishing          Husband   White
# 15873   Married-civ-spouse      Craft-repair          Husband   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 24564   Female             0             0              50   United-States
# 29642     Male             0             0              50   United-States
# 4925      Male             0             0              18   United-States
# 15568     Male             0             0              40   United-States
# 15873     Male             0             0              40   United-States
#
#        salary
# 24564   <=50K
# 29642    >50K
# 4925    <=50K
# 15568   <=50K
# 15873    >50K

# %%
str_column = []
num_column = []
for x in dt.columns:
    if dt[x].dtypes == 'object':
        dt[x] = dt[x].str.strip()
        dt[x].replace('?','NA',inplace=True)
        str_column.append(x)
    else:
        num_column.append(x)
        
dt['salary'].replace('>50K', 1, inplace=True)
dt['salary'].replace('<=50K', 0, inplace=True)
print(dt['salary'].value_counts())
print('>50K比例：',dt['salary'].value_counts()[1]/(dt['salary'].value_counts()[0]+dt['salary'].value_counts()[1]))
# Out:
# 0    24720
# 1     7841
# Name: salary, dtype: int64
# >50K比例： 0.2408095574460244

# %%
dt.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week        salary
# count    32561.000000  32561.000000
# mean        40.437456      0.240810
# std         12.347429      0.427581
# min          1.000000      0.000000
# 25%         40.000000      0.000000
# 50%         40.000000      0.000000
# 75%         45.000000      0.000000
# max         99.000000      1.000000

# %%
cont_col = [x for x in dt.describe().columns]
corr = dt[cont_col].corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col3 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col4 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col6 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row1_col3 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row1_col4 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row2_col0 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row2_col1 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row2_col3 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row2_col4 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row2_col5 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row2_col6 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row3_col0 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row3_col1 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row3_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row3_col5 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row3_col6 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row4_col0 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row4_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row4_col2 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row4_col5 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row4_col6 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row5_col0 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row5_col1 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row5_col2 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row5_col3 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row5_col4 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row5_col6 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row6_col0 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row6_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row6_col2 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row6_col3 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row6_col4 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row6_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_1a0a136e_cd77_11e9_b40e_42490f06fc43row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_1a0a136e_cd77_11e9_b40e_42490f06fc43" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >fnlwgt</th>        <th class="col_heading level0 col2" >education-num</th>        <th class="col_heading level0 col3" >capital-gain</th>        <th class="col_heading level0 col4" >capital-loss</th>        <th class="col_heading level0 col5" >hours-per-week</th>        <th class="col_heading level0 col6" >salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a0a136e_cd77_11e9_b40e_42490f06fc43level0_row0" class="row_heading level0 row0" >age</th>
#                         <td id="T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col1" class="data row0 col1" >-0.077</td>
#                         <td id="T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col2" class="data row0 col2" >0.037</td>
#                         <td id="T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col3" class="data row0 col3" >0.078</td>
#                         <td id="T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col4" class="data row0 col4" >0.058</td>
#                         <td id="T_1a0a136e_cd77_11e9_b40e_42490f06fc43row0_col5" class="data row0 col5" >0.069</td>
#                         <td id="T_1a0a136e_cd77_11e9_b40e_42490

# %%
dt = dt.drop(['fnlwgt'], axis = 1 )

# %%
cont_col = [x for x in dt.describe().columns][:-1]
X_logit = dt[cont_col]
y_logit = dt['salary']
sc = StandardScaler()
X_logit = pd.DataFrame(sc.fit_transform(X_logit))
X_logit.describe()
# Out:
#                   0             1             2             3             4
# count  3.256100e+04  3.256100e+04  3.256100e+04  3.256100e+04  3.256100e+04
# mean  -2.684093e-17  1.479525e-16  1.156560e-17 -4.538954e-17 -2.793203e-17
# std    1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00
# min   -1.582206e+00 -3.529656e+00 -1.459205e-01 -2.166595e-01 -3.194030e+00
# 25%   -7.757679e-01 -4.200596e-01 -1.459205e-01 -2.166595e-01 -3.542945e-02
# 50%   -1.159546e-01 -3.136003e-02 -1.459205e-01 -2.166595e-01 -3.542945e-02
# 75%    6.904838e-01  7.460392e-01 -1.459205e-01 -2.166595e-01  3.695194e-01
# max    3.769612e+00  2.300838e+00  1.339458e+01  1.059351e+01  4.742967e+00

# %%
clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial').fit(X_logit, y_logit)

# %%
print(cont_col)
print(clf.coef_)
# Out:
# ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
# [[0.29334828 0.41506075 1.1737482  0.14079209 0.25136639]]
